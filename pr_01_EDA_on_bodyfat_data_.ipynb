# %%
# Practical no 01
# Date :- 22-9-25
# Day :- Monday
# Title :- EDA on bodyfat  data

# %%
import pandas as pd

# %%
df=pd.read_csv('bodyfat.csv')

# %%
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
# Dataset size
df.shape
# Out:
# (252, 15)

# %%
df.columns
# Out:
# Index(['Density', 'BodyFat', 'Age', 'Weight', 'Height', 'Neck', 'Chest',
#        'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm',
#        'Wrist'],
#       dtype='object')

# %%
# describe data type of given dataset
df.dtypes
# Out:
# Density    float64
# BodyFat    float64
# Age          int64
# Weight     float64
# Height     float64
# Neck       float64
# Chest      float64
# Abdomen    float64
# Hip        float64
# Thigh      float64
# Knee       float64
# Ankle      float64
# Biceps     float64
# Forearm    float64
# Wrist      float64
# dtype: object

# %%
# describe the dataset ( You get only for numeric column)
df.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %%
#
df.isnull().sum()
# Out:
# Density    0
# BodyFat    0
# Age        0
# Weight     0
# Height     0
# Neck       0
# Chest      0
# Abdomen    0
# Hip        0
# Thigh      0
# Knee       0
# Ankle      0
# Biceps     0
# Forearm    0
# Wrist      0
# dtype: int64

# %%
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
# Give me those patient data whose chest size is above 95

# %%
df[df['Chest'] >=95 ]
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# 5     1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8
# 6     1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 246   1.0308     30.2   69  215.50   70.50  40.8  113.7    107.6  110.0
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# ...

# %%
# Find the average height of patients
df['Height'].mean()
# Out:
# 70.14880952380952

# %%
df[(df['Age'] > 25) & ( df['Weight']>180 )]
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 6     1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
# 10    1.0830      7.1   26  186.25   74.50  38.5  101.5     83.6   98.2
# 11    1.0812      7.8   27  216.00   76.00  39.4  103.6     90.9  107.7
# 12    1.0513     20.8   32  180.50   69.50  38.4  102.0     91.6  103.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 246   1.0308     30.2   69  215.50   70.50  40.8  113.7    107.6  110.0
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# ...

# %%
df.corr()
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966 -0.682599
# BodyFat -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592  0.702620
# Age     -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505  0.176450
# Weight  -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716  0.894191
# Height   0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710  0.134892
# Neck    -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000  0.784835
# Chest   -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835  1.000000
# Abdomen -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077  0.915828
# Hip     -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958  0.829420
# Thigh   -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697  0.729859
# Knee    -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405  0.719496
# ...

# %%
df[(25 <df['Age'] > 30) &  ( 180<df['Weight']>210)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23120\940283690.py in <module>
# ----> 1 df[(25 <df['Age'] > 30) &  ( 180<df['Weight']>210)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df['Age'] > 25)  & (df['Age'] < 30)  & (df['Weight'] > 180 ) & ( df['Weight'] < 210 )]
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 6     1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
# 10    1.0830      7.1   26  186.25   74.50  38.5  101.5     83.6   98.2
# 18    1.0622     16.0   28  183.75   67.75  38.0  106.8     89.6  102.4
# 21    1.0640     15.2   28  200.50   69.75  41.3  111.4     98.8  104.8
# 154   1.0510     21.0   27  200.25   73.50  38.2  101.1    100.1  105.0
# 156   1.0287     31.2   28  205.75   69.00  38.5  105.6    105.0  106.4
# 157   1.0761     10.0   28  182.50   72.25  37.0   98.5     90.8  102.5
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 6     58.4  38.3   22.9    31.9     27.8   17.7
# 10    59.7  39.7   25.2    32.8     29.4   18.5
# 18    64.2  38.7   22.9    37.2     30.5   18.5
# 21    63.4  40.6   24.6    33.0     32.8   19.9
# ...
