# %%
import pandas as pd
df=pd.read_csv('iris.data.csv')
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.shape
# Out:
# (149, 5)

# %%
df.isnull().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
df.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.tail(20)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 129  7.4  2.8  6.1  1.9  Iris-virginica
# 130  7.9  3.8  6.4  2.0  Iris-virginica
# 131  6.4  2.8  5.6  2.2  Iris-virginica
# 132  6.3  2.8  5.1  1.5  Iris-virginica
# 133  6.1  2.6  5.6  1.4  Iris-virginica
# 134  7.7  3.0  6.1  2.3  Iris-virginica
# 135  6.3  3.4  5.6  2.4  Iris-virginica
# 136  6.4  3.1  5.5  1.8  Iris-virginica
# 137  6.0  3.0  4.8  1.8  Iris-virginica
# 138  6.9  3.1  5.4  2.1  Iris-virginica
# 139  6.7  3.1  5.6  2.4  Iris-virginica
# 140  6.9  3.1  5.1  2.3  Iris-virginica
# 141  5.8  2.7  5.1  1.9  Iris-virginica
# 142  6.8  3.2  5.9  2.3  Iris-virginica
# 143  6.7  3.3  5.7  2.5  Iris-virginica
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
import matplotlib.pyplot as plt
x=df['5.1']
y=df['3.5']
plt.scatter(x,y)
plt.xlabel("5.1")
plt.ylabel("3.5")
plt.title("Scatter plot of years of 5.1 and 3.5")
# Out:
# Text(0.5, 1.0, 'Scatter plot of years of 5.1 and 3.5')

# %%
x=df['5.1']
y=df['Iris-setosa']
plt.scatter(x,y)
plt.xlabel("5.1")
plt.ylabel("Iris-setosa")
plt.title("Scatter plot of years of 5.1 and Iris-setosa")
# Out:
# Text(0.5, 1.0, 'Scatter plot of years of 5.1 and Iris-setosa')

# %%
x=df['0.2']
y=df['Iris-setosa']
plt.scatter(x,y)
plt.xlabel("5.1")
plt.ylabel("Iris-setosa")
plt.title("Scatter plot of years of 5.1 and Iris-setosa")
# Out:
# Text(0.5, 1.0, 'Scatter plot of years of 5.1 and Iris-setosa')

# %%
x=df['1.4']
y=df['5.1']
plt.scatter(x,y)
plt.xlabel("1.4")
plt.ylabel("5.1")
plt.title("Scatter plot of years of 1.4 and 5.1")
# Out:
# Text(0.5, 1.0, 'Scatter plot of years of 1.4 and 5.1')

# %%
x=df['1.4']
y=df['0.2']
plt.scatter(x,y)
plt.xlabel("1.4")
plt.ylabel("0.2")
plt.title("Scatter plot of years of 1.4 and 0.2")
# Out:
# Text(0.5, 1.0, 'Scatter plot of years of 1.4 and 0.2')

# %%
plt.plot(df['5.1'],'dg')
plt.plot(df['3.5'],'*k')
plt.plot(df['0.2'],'dr')
plt.plot(df['1.4'],'.')
plt.plot(df['Iris-setosa'],'dk')
