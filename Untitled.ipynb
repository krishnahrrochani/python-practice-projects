# %%
import pandas as pd
data = {'Scores': [85 ,90 ,78 ,92 ,88]}
df = pd.DataFrame(data)
average_score = df['Scores'].mean()
print(f"The average score is: {average_score}")
# Out:
# The average score is: 86.6

# %%
data = {'Age': [25 ,30 ,35 ,40 ,25], 'Salary': [50000 ,60000 ,70000 ,80000 ,50000]}
df = pd.DataFrame(data)
summary = df.describe()
print(summary)
# Out:
#              Age       Salary
# count   5.000000      5.00000
# mean   31.000000  62000.00000
# std     6.519202  13038.40481
# min    25.000000  50000.00000
# 25%    25.000000  50000.00000
# 50%    30.000000  60000.00000
# 75%    35.000000  70000.00000
# max    40.000000  80000.00000

# %%
n = 6
for i in range(1 ,n+1):
    for j in range(1 ,i+1):
        print(j, end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
# 123456

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25 ,30]
plt.plot(x, y, marker = 'o')

plt.xlabel('Time (Units)')
plt.ylabel('Value')
plt.title ('Data Trend Analysis')
plt.grid(True)
plt.show()

# %%
categories = ['A', 'B', 'C' , 'D']
values = [15, 27, 10, 35]

plt.bar(categories, values, color='skyblue')

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Comparison of Categories')
plt.show()

# %%
num1  = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == '+':
    print(f"Result: {num1 + num2}")
elif operator == '-':
    print(f"Result: {num1 - num2}")
elif operator == '*':
    print(f"Result: {num1 * num2}")
elif operator == '/':
    if num2 != 0:
        print(f"Result: {num1/num2}")
    else:
        print("Error: Division by zero is not allowed.")
else:
    print("Invalid operator selected>")
# Out:
# Enter first number:  10
# Enter second number:  20
# Enter operator (+, -, *, /):  +
# Result: 30.0

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2,int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

number = int(input("Enter a number: "))
if is_prime(number):
    print(f"{number} is a prime number. ")
else:
    print(f"{number} is not a prime number.")
# Out:
# Enter a number:  29
# 29 is a prime number.
